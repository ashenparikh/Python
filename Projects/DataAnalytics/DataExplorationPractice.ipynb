# %% [markdown]
# Goals for excercise
# 1. Load data as dataframe > Data Questions CHECK
# 2. Perform Univariate Analysis
# 3. Explore Unexpected Values > Reconcile this
# 4. Explore Variables
# 5. Remove Unuseful data
# 6. Explore Correlations beetween variables

# %% [markdown]
# Changed jupyter settings to accomodate data rate:  jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
# **Data Limit permanently changed until changed back**

# %% [markdown]
# Policy Level, County Level, Multiple types of limits per policy, tiv?, deductible, line, construction, point of granularity
#
# Data: Correlation or Causation relationships
#
# Definition:
# Deductible:  is the amount paid out of pocket by the policy holder before an insurance provider will pay any expenses
# TIV: Highest site limit value
#
# Context: Insurance per site considering different limits in Florida. What was the total insured value of the site. Compared the TIV between 2011 and 2012. (Story/Reason for Analysis) Insurance company is tracking the total insured value of a site across years. It seems they are increasing the total insured values.
#
# Questions:
# Per county are there different policy limits? > Combine with financial data to re-calculate limits
#
# Data Goal:
# Visualize Holistic change in insurance value per year and a zoomed in version per site for a company.

# %%
import pandas as pd
df = pd.read_csv("/Users/ashenparikh/Downloads/FL_insurance_sample.csv")

# %%
df.columns
# Out:
# Index(['policyID', 'statecode', 'county', 'eq_site_limit', 'hu_site_limit',
#        'fl_site_limit', 'fr_site_limit', 'tiv_2011', 'tiv_2012',
#        'eq_site_deductible', 'hu_site_deductible', 'fl_site_deductible',
#        'fr_site_deductible', 'point_latitude', 'point_longitude', 'line',
#        'construction', 'point_granularity'],
#       dtype='object')

# %%
df.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
df.shape
# Out:
# (36634, 18)

# %%
df.nunique(axis=0)
# Out:
# policyID              36634
# statecode                 1
# county                   67
# eq_site_limit          5961
# hu_site_limit         24531
# fl_site_limit          4581
# fr_site_limit          7536
# tiv_2011              24804
# tiv_2012              35295
# eq_site_deductible      155
# hu_site_deductible     2153
# fl_site_deductible       43
# fr_site_deductible        6
# point_latitude        17900
# point_longitude       17731
# line                      2
# construction              5
# point_granularity         5
# dtype: int64

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#             policyID      eq_site_limit      hu_site_limit      fl_site_limit  \
# count   36634.000000       36634.000000       36634.000000       36634.000000
# mean   548661.937189      731478.006846     2074347.928476      664600.937028
# std    259912.926494    17523003.588415    19641497.135377    17461144.429799
# min    100074.000000           0.000000           0.000000           0.000000
# 25%    323647.750000           0.000000       42481.060000           0.000000
# 50%    548525.000000           0.000000      192691.085000           0.000000
# 75%    774252.000000           0.000000      916338.060000           0.000000
# max    999971.000000  2160000000.000000  2160000000.000000  2160000000.000000
#
#            fr_site_limit           tiv_2011           tiv_2012  \
# count       36634.000000       36634.000000       36634.000000
# mean       991172.355861     2172875.000323     2571004.097342
# std      17671776.714882    20150151.203414    20367766.569178
# ...
